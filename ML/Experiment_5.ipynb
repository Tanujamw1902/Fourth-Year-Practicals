# %% [markdown]
# Name:-Tanuja Maruti Waware B.E. Division:- C Batch:- C3 Roll No.:- 14366

# %% [markdown]
# # Experiment No.:-5

# %%
import matplotlib.pyplot as plt

# %%
# Initialize variables
precision = 0.0001  # Desired precision
previous_step_size = 1  # Large initial value to ensure the loop starts
iters = 0  # Iteration counter
max_iter = 1000  # Maximum number of iterations
lr = 0.01  # Learning rate
x = 0  # Initial value of x
gd = []  # List to store the values of x

# Gradient descent loop
while previous_step_size > precision and iters < max_iter:
    prev = x
    x = x - lr * gf(prev)  # Update x using the gradient
    previous_step_size = abs(x - prev)  # Calculate step size
    iters += 1  # Increment iteration counter
    print('Iteration:', iters, 'Value:', x)
    gd.append(x)  # Store the current value of x

# After the loop, x should be close to the minimum value
# Out:
# Iteration: 1 Value: -0.09
# Iteration: 2 Value: -0.17468100000000003
# Iteration: 3 Value: -0.25450527451761
# Iteration: 4 Value: -0.32988268739412624
# Iteration: 5 Value: -0.40117795202490236
# Iteration: 6 Value: -0.4687167123953172
# Iteration: 7 Value: -0.5327906632163849
# Iteration: 8 Value: -0.5936618823315074
# Iteration: 9 Value: -0.6515665136969508
# Iteration: 10 Value: -0.7067179120928457
# Iteration: 11 Value: -0.7593093394400037
# Iteration: 12 Value: -0.8095162858032116
# Iteration: 13 Value: -0.8574984748248251
# Iteration: 14 Value: -0.9034016026786046
# Iteration: 15 Value: -0.947358851075111
# Iteration: 16 Value: -0.9894922079377079
# Iteration: 17 Value: -1.0299136237571398
# Iteration: 18 Value: -1.068726027055717
# Iteration: 19 Value: -1.106024218641437
# Iteration: 20 Value: -1.141895661245165
# Iteration: 21 Value: -1.1764211785821603
# Iteration: 22 Value: -1.209675575761397
# Iteration: 23 Value: -1.24172819120165
# ...

# %%
print('Local Minima:', x)
# Out:
# Local Minima: -2.900174803000465

# %%
plt.plot(gd)
